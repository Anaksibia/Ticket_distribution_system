# %% [markdown]
# # Hierarchical model

# %%
import pandas as pd
import numpy as np
import sklearn.metrics
import xgboost as xgb
import mlflow

from sklearn.metrics import mean_absolute_error as mape
from sklearn.metrics import mean_squared_error as mse
from category_encoders import *

# %%
train_df = pd.read_csv('../data/preprocessed/train_df.csv',
                       sep=',', index_col=0)
test_df = pd.read_csv('../data/preprocessed/test_df.csv',
                       sep=',', index_col=0)

train_df.head()
# Out:
# /Users/alenalapteva/anaconda3/envs/alapteva-time-series/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             game_code  ops_num  last_year_sales  general_sales  \
# 2017-02-12       7101   105005              NaN          719.0
# 2017-02-19       7101   105005              NaN          731.0
# 2017-02-26       7101   105005              NaN         1092.0
# 2017-03-05       7101   105005              NaN         1614.0
# 2017-03-12       7101   105005              NaN         1296.0
#
#             game_code_sales  ops_num_sales  sales  \
# 2017-02-12              NaN            NaN   25.0
# 2017-02-19              NaN            NaN   16.0
# 2017-02-26              NaN            NaN   17.0
# 2017-03-05              NaN            NaN   15.0
# 2017-03-12              NaN            NaN   19.0
#
#             mean_w12__benford_correlation  mean_w8__benford_correlation  \
# 2017-02-12                            NaN                           NaN
# 2017-02-19                            NaN                           NaN
# 2017-02-26                            NaN                           NaN
# 2017-03-05                            NaN                           NaN
# 2017-03-12                            NaN                           NaN
#
#             mean_w8__abs_energy  ...  mean_w12__minimum  \
# 2017-02-12                  NaN  ...                NaN
# 2017-02-19                  NaN  ...                NaN
# 2017-02-26                  NaN  ...                NaN
# 2017-03-05                  NaN  ...                NaN
# 2017-03-12                  NaN  ...                NaN
#
#             previous__benford_correlation  deviation__benford_correlation  \
# 2017-02-12                            NaN                             NaN
# 2017-02-19                            NaN                             NaN
# 2017-02-26                            NaN                             NaN
# 2017-03-05                            NaN                             NaN
# 2017-03-12                            NaN                             NaN
#
#             deviation__fft_coefficient__attr_"angle"__coeff_0  \
# 2017-02-12                                                NaN
# 2017-02-19                                                NaN
# 2017-02-26                                                NaN
# 2017-03-05                                                NaN
# 2017-03-12                                                NaN
#
#             deviation__range_count__max_1000000000000.0__min_0  \
# 2017-02-12                                                NaN
# 2017-02-19                                                NaN
# 2017-02-26                                                NaN
# 2017-03-05                                                NaN
# 2017-03-12                                                NaN
#
#             deviation__count_above__t_0  deviation__count_below__t_0  \
# 2017-02-12                          NaN                          NaN
# 2017-02-19                          NaN                          NaN
# 2017-02-26                          NaN                          NaN
# 2017-03-05                          NaN                          NaN
# 2017-03-12                          NaN                          NaN
#
#             deviation__range_count__max_1__min_-1  \
# 2017-02-12                                    NaN
# 2017-02-19                                    NaN
# 2017-02-26                                    NaN
# 2017-03-05                                    NaN
# 2017-03-12                                    NaN
#
#             deviation__fft_coefficient__attr_"abs"__coeff_0  \
# 2017-02-12                                              NaN
# 2017-02-19                                              NaN
# 2017-02-26                                              NaN
# 2017-03-05                                              NaN
# 2017-03-12                                              NaN
#
#             deviation__abs_energy
# 2017-02-12                    NaN
# 2017-02-19                    NaN
# 2017-02-26                    NaN
# 2017-03-05                    NaN
# 2017-03-12                    NaN
#
# [5 rows x 117 columns]

# %%
y_train = train_df["sales"]
y_test = test_df["sales"]
X_train = train_df.drop(["sales"], axis=1)
X_test = test_df.drop(["sales"], axis=1)
# Out:
# /Users/alenalapteva/anaconda3/envs/alapteva-time-series/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# use binary encoding to encode two categorical features
enc = BinaryEncoder(cols=['game_code', 'ops_num']).fit(X_train)

# transform the dataset
train_numeric_dataset = enc.transform(X_train)
test_numeric_dataset = enc.transform(X_test)

print(test_numeric_dataset.head())
# Out:
# /Users/alenalapteva/anaconda3/envs/alapteva-time-series/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
#             game_code_0  game_code_1  game_code_2  game_code_3  ops_num_0  \
# 2018-11-04            0            0            0            1          0
# 2018-11-11            0            0            0            1          0
# 2018-11-18            0            0            0            1          0
# 2018-11-25            0            0            0            1          0
# 2018-12-02            0            0            0            1          0
#
#             ops_num_1  ops_num_2  ops_num_3  ops_num_4  ops_num_5  ...  \
# 2018-11-04          0          0          0          0          0  ...
# 2018-11-11          0          0          0          0          0  ...
# 2018-11-18          0          0          0          0          0  ...
# 2018-11-25          0          0          0          0          0  ...
# 2018-12-02          0          0          0          0          0  ...
#
#             mean_w12__minimum  previous__benford_correlation  \
# 2018-11-04                NaN                            NaN
# 2018-11-11                NaN                            NaN
# 2018-11-18                NaN                            NaN
# 2018-11-25                NaN                            NaN
# 2018-12-02                NaN                            NaN
#
#             deviation__benford_correlation  \
# 2018-11-04                             NaN
# 2018-11-11                             NaN
# 2018-11-18                             NaN
# 2018-11-25                             NaN
# 2018-12-02                             NaN
#
#             deviation__fft_coefficient__attr_"angle"__coeff_0  \
# 2018-11-04                                                NaN
# 2018-11-11                                                NaN
# 2018-11-18                                                NaN
# 2018-11-25                                                NaN
# 2018-12-02                                                NaN
#
#             deviation__range_count__max_1000000000000.0__min_0  \
# 2018-11-04                                                NaN
# 2018-11-11                                                NaN
# 2018-11-18                                                NaN
# 2018-11-25                                                NaN
# 2018-12-02                                                NaN
#
#             deviation__count_above__t_0  deviation__count_below__t_0  \
# 2018-11-04                          NaN                          NaN
# 2018-11-11                          NaN                          NaN
# 2018-11-18                          NaN                          NaN
# 2018-11-25                          NaN                          NaN
# 2018-12-02                          NaN                          NaN
#
#             deviation__range_count__max_1__min_-1  \
# 2018-11-04                                    NaN
# 2018-11-11                                    NaN
# 2018-11-18                                    NaN
# 2018-11-25                                    NaN
# 2018-12-02                                    NaN
#
#             deviation__fft_coefficient__attr_"abs"__coeff_0  \
# 2018-11-04                                              NaN
# 2018-11-11                                              NaN
# 2018-11-18                                              NaN
# 2018-11-25                                              NaN
# 2018-12-02                                              NaN
#
#             deviation__abs_energy
# 2018-11-04                    NaN
# 2018-11-11                    NaN
# 2018-11-18                    NaN
# 2018-11-25                    NaN
# 2018-12-02                    NaN
#
# [5 rows x 126 columns]

# %%
# %time
from mlflow.models.signature import infer_signature

with mlflow.start_run(run_name='XGBoost_base_all_ts'):
    xgb_regressor = xgb.XGBRegressor(
            n_estimators=100,
            reg_lambda=1,
            gamma=0,
            max_depth=6
        )
    xgb_regressor.fit(train_numeric_dataset, y_train)
    
    signature = infer_signature(train_numeric_dataset, xgb_regressor.predict(train_numeric_dataset))
    mlflow.sklearn.log_model(xgb_regressor, "XGB_base_all_ts", signature=signature)
    mape_base_xgb = mape(y_test.to_numpy(), xgb_regressor.predict(test_numeric_dataset))
    rmse_base_xgb = mse(y_test.to_numpy(), xgb_regressor.predict(test_numeric_dataset), squared=False)
    mlflow.log_metric("mape", mape_base_xgb)
    mlflow.log_metric("rmse", rmse_base_xgb)

print(mape_base_xgb)
print(rmse_base_xgb)
# Out:
# /Users/alenalapteva/anaconda3/envs/alapteva-time-series/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# CPU times: user 21 µs, sys: 16 µs, total: 37 µs
# Wall time: 1.6 ms
# 43.24498949672859
# 195.78439633625948

# %%
import optuna

optuna.logging.set_verbosity(optuna.logging.WARNING)
    
def objective(trial):
    dtrain = xgb.DMatrix(train_numeric_dataset, label=y_train)
    dtest = xgb.DMatrix(test_numeric_dataset, label=y_test)

    param = {
        "silent": 1,
        "objective": "reg:squarederror",
        "eval_metric": "rmse",
        "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
        "lambda": trial.suggest_loguniform("lambda", 1e-8, 1.0),
        "alpha": trial.suggest_loguniform("alpha", 1e-8, 1.0),
    }

    if param["booster"] == "gbtree" or param["booster"] == "dart":
        param["max_depth"] = trial.suggest_int("max_depth", 1, 9)
        param["eta"] = trial.suggest_loguniform("eta", 1e-8, 1.0)
        param["gamma"] = trial.suggest_loguniform("gamma", 1e-8, 1.0)
        param["grow_policy"] = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])
    if param["booster"] == "dart":
        param["sample_type"] = trial.suggest_categorical("sample_type", ["uniform", "weighted"])
        param["normalize_type"] = trial.suggest_categorical("normalize_type", ["tree", "forest"])
        param["rate_drop"] = trial.suggest_loguniform("rate_drop", 1e-8, 1.0)
        param["skip_drop"] = trial.suggest_loguniform("skip_drop", 1e-8, 1.0)

    # Add a callback for pruning.
    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, "validation-rmse")
    bst = xgb.train(param, dtrain, evals=[(dtest, "validation")], callbacks=[pruning_callback])
    preds = bst.predict(dtest)
    metric = mse(y_test, preds, squared=False)
    return metric

study = optuna.create_study()
study.optimize(objective, n_trials=100)

print(study.best_value)
# Out:
# [12:49:20] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:231.95392
# [1]	validation-rmse:231.95342
# [2]	validation-rmse:231.95287
# [3]	validation-rmse:231.95227
# [4]	validation-rmse:231.95167
# [5]	validation-rmse:231.95113
# [6]	validation-rmse:231.95062
# [7]	validation-rmse:231.95007
# [8]	validation-rmse:231.94959
# [9]	validation-rmse:231.94908
# [12:49:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse
30] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.69542
# [1]	validation-rmse:198.90717
# [2]	validation-rmse:198.57042
# [3]	validation-rmse:198.39333
# [4]	validation-rmse:198.30144
# [5]	validation-rmse:198.25110
# [6]	validation-rmse:198.22172
# [7]	validation-rmse:198.24162
# [8]	validation-rmse:198.20897
# [9]	validation-rmse:198.18704
# [12:49:30] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.69112
# [1]	validation-rmse:198.91360
# [2]	validation-rmse:198.55968
# [3]	validation-rmse:198.38942
# [4]	validation-rmse:198.27895
# [5]	validation-rmse:198.22839
# [6]	validation-rmse:198.23073
# [7]	validation-rmse:198.20425
# [8]	validation-rmse:198.19672
# [9]	validation-rmse:198.20514
# [12:49:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.66806
# [1]	validation-rmse:198.90958
# [2]	validation-rmse:198.53633
# [3]	validation-rmse:198.37483
# [4]	validation-rmse:198.27269
# [5]	validation-rmse:198.24712
# [6]	validation-rmse:198.20409
# [7]	validation-rmse:198.20677
# [8]	validation-rmse:198.17940
# [9]	validation-rmse:198.17842
# [12:49:31] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:32] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.72559
# [1]	validation-rmse:198.90025
# [2]	validation-rmse:198.58214
# [3]	validation-rmse:198.37579
# [4]	validation-rmse:198.31305
# [5]	validation-rmse:198.25307
# [6]	validation-rmse:198.20509
# [7]	validation-rmse:198.18631
# [8]	validation-rmse:198.19472
# [9]	validation-rmse:198.18309
# [12:49:32] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.66945
# [1]	validation-rmse:198.89237
# [2]	validation-rmse:198.53529
# [3]	validation-rmse:198.35915
# [4]	validation-rmse:198.26640
# [5]	validation-rmse:198.21217
# [6]	validation-rmse:198.19132
# [7]	validation-rmse:198.18312
# [8]	validation-rmse:198.19490
# [9]	validation-rmse:198.18152
# [12:49:32] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:198.80904
# [1]	validation-rmse:198.42699
# [2]	validation-rmse:198.31625
# [3]	validation-rmse:198.27095
# [4]	validation-rmse:198.27428
# [5]	validation-rmse:198.27872
# [6]	validation-rmse:198.27969
# [7]	validation-rmse:198.26761
# [12:49:33] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:33] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.67740
# [1]	validation-rmse:198.87236
# [2]	validation-rmse:198.52390
# [3]	validation-rmse:198.39325
# [4]	validation-rmse:198.28856
# [5]	validation-rmse:198.23789
# [6]	validation-rmse:198.18571
# [7]	validation-rmse:198.19142
# [8]	validation-rmse:198.19241
# [9]	validation-rmse:198.18738
# [12:49:34] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.69975
# [12:49:34] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.68736
# [1]	validation-rmse:198.91722
# [2]	validation-rmse:198.55981
# [3]	validation-rmse:198.37233
# [4]	validation-rmse:198.28383
# [5]	validation-rmse:198.24597
# [6]	validation-rmse:198.19693
# [7]	validation-rmse:198.18617
# [8]	validation-rmse:198.19443
# [9]	validation-rmse:198.17900
# [12:49:34] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:34] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:35] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.68828
# [1]	validation-rmse:198.88544
# [2]	validation-rmse:198.54056
# [3]	validation-rmse:198.36749
# [4]	validation-rmse:198.28082
# [5]	validation-rmse:198.23338
# [6]	validation-rmse:198.20840
# [7]	validation-rmse:198.19012
# [8]	validation-rmse:198.17127
# [9]	validation-rmse:198.17570
# [12:49:35] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199
49] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:49] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:50] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.68741
# [12:49:50] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.66795
# [1]	validation-rmse:198.90122
# [2]	validation-rmse:198.54416
# [3]	validation-rmse:198.37146
# [4]	validation-rmse:198.28374
# [5]	validation-rmse:198.23671
# [6]	validation-rmse:198.20714
# [7]	validation-rmse:198.19978
# [12:49:50] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:50] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.67770
# [1]	validation-rmse:198.90294
# [2]	validation-rmse:198.53749
# [3]	validation-rmse:198.37013
# [4]	validation-rmse:198.27631
# [5]	validation-rmse:198.23036
# [6]	validation-rmse:198.20213
# [7]	validation-rmse:198.18643
# [8]	validation-rmse:198.17827
# [9]	validation-rmse:198.17421
# [12:49:51] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:51] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.68553
# [12:49:51] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.26703
# [1]	validation-rmse:198.62260
# [2]	validation-rmse:198.43249
# [3]	validation-rmse:198.35550
# [12:49:52] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.68501
# [1]	validation-rmse:198.90239
# [2]	validation-rmse:198.55212
# [3]	validation-rmse:198.37492
# [4]	validation-rmse:198.28757
# [5]	validation-rmse:198.23102
# [6]	validation-rmse:198.20810
# [7]	validation-rmse:198.19394
# [8]	validation-rmse:198.18401
# [9]	validation-rmse:198.17650
# [12:49:52] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:52] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:52] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:53] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:53] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:53] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.66197
# [1]	validation-rmse:198.89735
# [2]	validation-rmse:198.54736
# [3]	validation-rmse:198.37181
# [4]	validation-rmse:198.26892
# [5]	validation-rmse:198.22784
# [6]	validation-rmse:198.21091
# [12:49:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.55144
# [12:49:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.42806
# [1]	validation-rmse:198.76900
# [2]	validation-rmse:198.49762
# [3]	validation-rmse:198.36845
# [12:49:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:55] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:55] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:55] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:55] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation-rmse:199.67236
# [1]	validation-rmse:198.89403
# [2]	validation-rmse:198.54077
# [3]	validation-rmse:198.36556
# [4]	validation-rmse:198.28079
# [5]	validation-rmse:198.22980
# [6]	validation-rmse:198.18884
# [7]	validation-rmse:198.19369
# [8]	validation-rmse:198.19812
# [12:49:56] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1598185652448/work/src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 198.1733511253756

# %%
print(study.best_params)
# Out:
# {'booster': 'gblinear', 'lambda': 1.2579329387874718e-06, 'alpha': 7.818178345020804e-05}
# /Users/alenalapteva/anaconda3/envs/alapteva-time-series/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
with mlflow.start_run(run_name='XGBoost_bst_all_ts'):
    xgb_bst = xgb.XGBRegressor(booster= 'gblinear', reg_lambda=1.2579329387874718e-06, alpha= 7.818178345020804e-05)
    xgb_bst.fit(train_numeric_dataset, y_train)
    
    signature = infer_signature(train_numeric_dataset, xgb_bst.predict(train_numeric_dataset))
    mlflow.sklearn.log_model(xgb_bst, "XGB_bst_all_ts", signature=signature)
    
    mape_bst_xgb = mape(y_test.to_numpy(), xgb_bst.predict(test_numeric_dataset))
    rmse_bst_xgb = mse(y_test.to_numpy(), xgb_bst.predict(test_numeric_dataset), squared=False)
    mlflow.log_metric("mape", mape_bst_xgb)
    mlflow.log_metric("rmse", rmse_bst_xgb)

print(mape_bst_xgb)
print(rmse_bst_xgb)
# Out:
# 44.49013728294498
# 197.74307846555098
